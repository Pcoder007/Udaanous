# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('steam_games.csv')

# %%
df['ID'] = range(1, len(df) + 1)

# %%
df
# Out:
#        steam_appid                  name               developers  \
# 0          2719580              勇者の伝説の勇者                 ['ぽけそう']
# 1          2719590         Light No Fire          ['Hello Games']
# 2          2719600  Lorhaven: Cursed War      ['GoldenGod Games']
# 3          2719610          PUIQ: Demons              ['Giammnn']
# 4          2719650        Project XSTING          ['Saucy Melon']
# ...            ...                   ...                      ...
# 71424      2294300     Touchdown Pinball  ['Super PowerUp Games']
# 71425      2294250     Speed Golf Royale      ['Mainframe Games']
# 71426      2294160         Isle of Swaps           ['Fuzz Force']
# 71427      2294130               Goobies               ['Knifes']
# 71428      2294630       WindowBlinds 11             ['Stardock']
#
#                     publishers  \
# 0                     ['ぽけそう']
# 1              ['Hello Games']
# 2          ['GoldenGod Games']
# 3                  ['Giammnn']
# ...

# %%
df.head()
# Out:
#    steam_appid                  name           developers  \
# 0      2719580              勇者の伝説の勇者             ['ぽけそう']
# 1      2719590         Light No Fire      ['Hello Games']
# 2      2719600  Lorhaven: Cursed War  ['GoldenGod Games']
# 3      2719610          PUIQ: Demons          ['Giammnn']
# 4      2719650        Project XSTING      ['Saucy Melon']
#
#             publishers                                         categories  \
# 0             ['ぽけそう']                ['Single-player', 'Family Sharing']
# 1      ['Hello Games']  ['Single-player', 'Multi-player', 'Co-op', 'On...
# 2  ['GoldenGod Games']  ['Single-player', 'Multi-player', 'PvP', 'Shar...
# 3          ['Giammnn']  ['Single-player', 'Steam Achievements', 'Famil...
# 4      ['Saucy Melon']  ['Single-player', 'Steam Achievements', 'Steam...
#
#                                           genres  required_age  \
# 0                            ['Casual', 'Indie']             0
# ...

# %%
df2 = pd.read_csv('Messy data set.csv')

# %%
joined_data = pd.merge(df, df2, on='ID',how=inner)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 joined_data = pd.merge(df, df2, on='ID',how=inner)
#
# NameError: name 'inner' is not defined

# %%
df2
# Out:
#      ID     Name         Age               Email    JoinDate    Salary
# 0     1    Alice          25   alice@example.com  01/01/2020     50000
# 1     2      Bob          30     bob@example.com  not a date     60000
# 2     2      Bob          30     bob@example.com  01/02/2020     60000
# 3     4  Charlie         NaN            charlie@  01/03/2020     70000
# 4     5    David  Twenty-two                 NaN  01/04/2020       NaN
# 5     6      Eve          45         eve@example  01/05/2020     90000
# 6     7    Frank          50  frank@@example.com  01/06/2020    100000
# 7     8    Grace          55   grace@example.com  01/07/2020  one lakh
# 8  nine    Heidi          60   heidi@example.com  2020.08.01    120000
# 9    10      NaN          65      10@example.com  01/09/2020    130000

# %%
Data = pd.read_excel('practice_data.xlsx')
Data
Data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
numeric_columns = ['Days Present', 'Sales Revenue Generated']
fig, axes = plt.subplots(1,2,figsize=(12,6))
for index, column in enumerate(numeric_columns):
    sns.kdeplot(Data[column],ax=axes[index],fill=True)
    axes[index].set_title('KDE Plot')
plt.tight_layout()
plt.show()

# %%
highest_no = Data['Sales Revenue Generated'].max()
print(highest_no)
# Out:
# 97797

# %%
M_data1 = pd.read_csv("H:\Bharat Digital Internship\My SQL\enrollments_data.csv")
M_data1
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1664\2774229655.py:1: SyntaxWarning: invalid escape sequence '\B'
#   M_data1 = pd.read_csv("H:\Bharat Digital Internship\My SQL\enrollments_data.csv")
#      Enrollment_ID  Student_ID  Course_ID     Semester Grade
# 0                1         193        198  Summer 2024     A
# 1                2         111         63  Spring 2024     D
# 2                3         132        187  Summer 2024     F
# 3                4          54         77    Fall 2023     D
# 4                5          38         19  Summer 2024     D
# ..             ...         ...        ...          ...   ...
# 195            196         189         45  Summer 2024     F
# 196            197          37         70  Spring 2024     D
# 197            198         141        105    Fall 2023     F
# 198            199         164         17  Summer 2024     A
# ...

# %%
M_data2 = pd.read_csv("H:\Bharat Digital Internship\My SQL\student_information.csv")
M_data2
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\piyus\AppData\Local\Temp\ipykernel_1664\3964519687.py:1: SyntaxWarning: invalid escape sequence '\B'
#   M_data2 = pd.read_csv("H:\Bharat Digital Internship\My SQL\student_information.csv")
#      Student_ID First_Name Last_Name  Age      Gender   Department       Year  \
# 0             1    Richard    Wilson   20  Non-Binary      Science   Freshman
# 1             2    Jessica    Garcia   23        Male     Medicine   Freshman
# 2             3      James    Miller   18        Male     Medicine     Senior
# 3             4   Patricia     Brown   24  Non-Binary     Business     Senior
# 4             5   Patricia     Jones   21      Female         Arts     Senior
# ..          ...        ...       ...  ...         ...          ...        ...
# 195         196   Jennifer     Jones   22        Male     Medicine  Sophomore
# ...

# %%
joined_data = pd.merge(M_data1, M_data2, on='Student_ID',how='inner')

# %%
joined_data
# Out:
#      Enrollment_ID  Student_ID  Course_ID     Semester Grade First_Name  \
# 0                1         193        198  Summer 2024     A    William
# 1                2         111         63  Spring 2024     D   Patricia
# 2                3         132        187  Summer 2024     F      Karen
# 3                4          54         77    Fall 2023     D     Robert
# 4                5          38         19  Summer 2024     D       Mary
# ..             ...         ...        ...          ...   ...        ...
# 195            196         189         45  Summer 2024     F   Jennifer
# 196            197          37         70  Spring 2024     D      James
# 197            198         141        105    Fall 2023     F    Barbara
# 198            199         164         17  Summer 2024     A       Mary
# 199            200          63         17    Fall 2023     C    Barbara
#
#     Last_Name  Age      Gender   Department       Year   GPA
# ...

# %%
from scipy.stats import boxcox
from scipy.stats import shapiro

# %%
def boxcox_transformation(Data, column_name):
    transformed_data, _ =boxcox(Data[column_name])
    Data[f"{column_name}_boxcox"] = transformed_data
    stat, p_value = shapiro(Data[f"{column_name}_boxcox"])
    kdeplot = sns.kdeplot(Data[f"{column_name}_boxcox"],fill=True)
    print(kdeplot)
    print("p_value:",p_value)

DF = pd.read_excel('practice_data.xlsx')
boxcox_transformation(DF,"Days Present")
# Out:
# Axes(0.125,0.11;0.775x0.77)
# p_value: 0.04714209034001586

# %%
from scipy.stats import yeojohnson
def yeojohnson_transformation(Data, column_name):
    transformed_data, _ =boxcox(Data[column_name])
    Data[f"{column_name}_yeojohnson"] = transformed_data
    stat, p_value = shapiro(Data[f"{column_name}_yeojohnson"])
    kdeplot = sns.kdeplot(Data[f"{column_name}_yeojohnson"],fill=True)
    print(kdeplot)
    print("p_value:",p_value)

DF = pd.read_excel('practice_data.xlsx')
yeojohnson_transformation(DF,"Days Present")
# Out:
# Axes(0.125,0.11;0.775x0.77)
# p_value: 0.04714209034001586

# %%
concatanet_data = pd.concat([M_data1, M_data2])
concatanet_data
# Out:
#      Enrollment_ID  Student_ID  Course_ID     Semester Grade First_Name  \
# 0              1.0         193      198.0  Summer 2024     A        NaN
# 1              2.0         111       63.0  Spring 2024     D        NaN
# 2              3.0         132      187.0  Summer 2024     F        NaN
# 3              4.0          54       77.0    Fall 2023     D        NaN
# 4              5.0          38       19.0  Summer 2024     D        NaN
# ..             ...         ...        ...          ...   ...        ...
# 195            NaN         196        NaN          NaN   NaN   Jennifer
# 196            NaN         197        NaN          NaN   NaN    Jessica
# 197            NaN         198        NaN          NaN   NaN    William
# 198            NaN         199        NaN          NaN   NaN       John
# 199            NaN         200        NaN          NaN   NaN      Karen
#
#     Last_Name   Age  Gender   Department       Year   GPA
# ...

# %%
cross_tab = pd.crosstab(M_data1['Grade'], M_data2['Gender'])
cross_tab
# Out:
# Gender  Female  Male  Non-Binary
# Grade
# A            8     7          12
# B           17     8          16
# C           14    10          15
# D           11    12          17
# F            7    11           9
# W           11     8           7

# %%
M_data1.dtypes
# Out:
# Enrollment_ID     int64
# Student_ID        int64
# Course_ID         int64
# Semester         object
# Grade            object
# dtype: object

# %%
M_data1['Grade'].value_counts()
# Out:
# Grade
# B    41
# D    40
# C    39
# A    27
# F    27
# W    26
# Name: count, dtype: int64

# %%
G_Data = M_data1.groupby('Grade')['Student_ID'].mean()

# %%
G_Data
# Out:
# Grade
# A    104.592593
# B     98.609756
# C     90.897436
# D     99.150000
# F     95.888889
# W    108.076923
# Name: Student_ID, dtype: float64

# %%
M_data1.describe()
# Out:
#        Enrollment_ID  Student_ID   Course_ID
# count     200.000000  200.000000  200.000000
# mean      100.500000   98.885000  100.345000
# std        57.879185   59.619074   60.984684
# min         1.000000    1.000000    1.000000
# 25%        50.750000   47.500000   40.750000
# 50%       100.500000   98.000000  103.500000
# 75%       150.250000  146.000000  154.000000
# max       200.000000  200.000000  200.000000

# %%
pivot_table = M_data1.pivot_table(index = 'Grade', values = ['Enrollment_ID','Student_ID'],aggfunc = {'Grade':'count','Enrollment_ID':'mean'})
pivot_table
# Out:
#        Enrollment_ID  Grade
# Grade
# A         110.518519     27
# B          97.682927     41
# C          94.076923     39
# D          97.725000     40
# F         105.888889     27
# W         102.846154     26

# %%
from scipy import stats
hypothesis_mean = 68
t_statistic, p_value = stats.ttest_1samp(Data["Interpersonal Skills Rating"],hypothesis_mean)
print("P-value",p_value)

alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference between the average Interpersonal Skills Rating and 68.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference between the average Interpersonal Skills Rating and 68.")
# Out:
# P-value 1.0318380146847296e-52
# Reject the null hypothesis. There is a significant difference between the average Interpersonal Skills Rating and 68.

# %%
Sales = Data.query('department == "Sales"')['Task Completion Rates']
Marketing = Data.query('department == "Marketing"')['Task Completion Rates']
Human_Resources = Data.query('department == "Human Resources"')['Task Completion Rates']
Engineering = Data.query('department == "Engineering"')['Task Completion Rates']
Finance = Data.query('department == "Finance"')['Task Completion Rates']

t_statistic, p_value = stats.f_oneway(Sales, Marketing, Human_Resources, Engineering, Finance)
print("P-value:", p_value)
                                                   
alpha = 0.05 
if p_value < alpha:
    print('Reject the null hypothesis. There is a significant difference in average frequency of purchases among the customers from different cities.')
else:
    print('Fail to reject the null hypothesis. There is no significant difference in average frequency of purchases among the customers from different cities.')
# Out:
# P-value: 0.592585693937975
# Fail to reject the null hypothesis. There is no significant difference in average frequency of purchases among the customers from different cities.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Days Present', y='Interpersonal Skills Rating', Data=Data, marker='o')
plt.title('Analyse')
plt.xlabel('Days Present')
plt.ylabel('Interpersonal Skills Rating')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 2
#       1 plt.figure(figsize=(12, 6))
# ----> 2 sns.lineplot(x='Days Present', y='Interpersonal Skills Rating', Data=Data, marker='o')
#       3 plt.title('Analyse')
#       4 plt.xlabel('Days Present')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
# ...

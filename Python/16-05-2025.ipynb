# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('practice_data.xlsx')

# %%
Data = pd.DataFrame(df)
Data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
df['Decision-Making Skills Rating'] = df['Decision-Making Skills Rating'].astype(float)

# %%
import numpy as np
df['Decision-Making Skills Rating'] = np.round(np.random.uniform(1.0, 5.0, size=len(df)), 2)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
# Apply label encoding to the 'gender' column
Data['Encoder_feature'] = encoder.fit_transform(Data['gender'])

# Display the first five rows
Data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy of Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
print("First value of gender after label encoding:", df['gender'][0])
# Out:
# First value of gender after label encoding: Male

# %%
x = df.drop(['Accuracy of Work','Meeting Project Deadlines'],axis = 1)
y = round(df['Decision-Making Skills Rating'],2)

# %%
x
# Out:
#     EmployeeID  gender       department  Days Present  Task Completion Rates  \
# 0            1    Male            Sales            20                     85
# 1            2  Female        Marketing            22                     90
# 2            3    Male  Human Resources            25                     80
# 3            4    Male      Engineering            19                     75
# 4            5  Female          Finance            23                     85
# 5            6    Male            Sales            21                     95
# 6            7  Female        Marketing            24                     70
# 7            8    Male  Human Resources            18                     80
# 8            9    Male      Engineering            20                     90
# 9           10  Female          Finance            22                     85
# 10          11    Male            Sales            25                     75
# ...

# %%
y
# Out:
# 0     2.22
# 1     4.14
# 2     1.00
# 3     4.43
# 4     1.35
# 5     1.69
# 6     3.49
# 7     4.06
# 8     4.44
# 9     3.84
# 10    1.30
# 11    4.07
# 12    4.81
# 13    1.49
# 14    2.29
# 15    2.70
# 16    3.17
# 17    2.93
# 18    1.88
# 19    5.00
# 20    1.88
# 21    3.62
# 22    4.31
# 23    1.02
# 24    2.38
# 25    4.14
# 26    2.83
# 27    1.03
# 28    4.20
# 29    1.54
# 30    3.53
# Name: Decision-Making Skills Rating, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df["Task Completion Rates"] = scaler.fit_transform(df[["Task Completion Rates",'Days Present','Interpersonal Skills Rating']])
df["Task Completion Rates"].head()
# Out:
# 0    0.854965
# 1    1.407129
# 2    0.302800
# 3   -0.249365
# 4    0.854965
# Name: Task Completion Rates, dtype: float64

# %%
from sklearn.decomposition import PCA

pca = PCA()
temp_pca = pca.fit_transform(df[["Task Completion Rates",'Days Present','Interpersonal Skills Rating']])

evr = pca.explained_variance_ratio_
plt.figure(figsize=(10,6))
plt.plot(range(1, len(evr) + 1), evr, marker='o')
plt.title('Explained Variance Ratio by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.show()


num_components = 3


pca = PCA(n_components=num_components)
x_pca = pca.fit_transform(df[["Task Completion Rates",'Days Present','Interpersonal Skills Rating']])

print(f"PCA result shape: {x_pca.shape}")
print("First few rows of PCA-transformed data:")
print(x_pca[:5])
# Out:
# PCA result shape: (31, 3)
# First few rows of PCA-transformed data:
# [[-1.21956987  1.43083181 -0.10540596]
#  [ 0.61568408  0.84801605  1.15834026]
#  [ 3.88477106  1.51495016 -0.59887697]
#  [-2.41191217 -0.74580022  0.1398204 ]
#  [ 1.6305556   0.43497032  0.8353622 ]]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = df[["Task Completion Rates",'Days Present','Interpersonal Skills Rating']]  # feature columns
y = df["Decision-Making Skills Rating"]  # target column

scaler = StandardScaler()
scaled = scaler.fit_transform(X)  # scaled is used below

x_train, x_test, y_train, y_test = train_test_split(scaled, y, test_size=0.2, random_state=42)

# %%
x_train, x_test, y_train, y_test
# Out:
# (array([[ 0.30279996, -0.58811969,  0.85707453],
#         [ 0.30279996,  0.7459079 ,  0.02678358],
#         [ 0.8549646 , -0.58811969,  0.85707453],
#         [ 0.8549646 ,  0.7459079 ,  0.02678358],
#         [ 0.8549646 , -0.58811969,  0.85707453],
#         [ 1.95929387, -0.14344383,  0.85707453],
#         [ 1.40712924, -0.14344383,  0.85707453],
#         [-0.80152931, -1.03279556, -0.80350738],
#         [-1.90585859,  1.19058377, -1.63379833],
#         [ 1.40712924,  0.30123204,  0.02678358],
#         [ 0.30279996,  1.63525964,  1.68736549],
#         [-1.35369395, -1.03279556, -0.80350738],
#         [-0.24936467, -1.03279556, -0.80350738],
#         [ 0.8549646 , -0.14344383,  0.85707453],
#         [-0.24936467,  0.7459079 ,  0.02678358],
#         [-0.80152931,  1.63525964,  1.68736549],
#         [ 0.30279996, -0.58811969,  0.85707453],
#         [-0.24936467,  0.7459079 ,  0.02678358],
#         [ 0.30279996, -1.47747142, -0.80350738],
# ...
